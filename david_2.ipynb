# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Define paths
train_dir = 'dataset/train'
test_dir = 'dataset/test'

# Load datasets
batch_size = 32
img_height = 224
img_width = 224

train_dataset = image_dataset_from_directory(
    train_dir,
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width)
)

test_dataset = image_dataset_from_directory(
    test_dir,
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width)
)

# Retrieve class names
class_names = train_dataset.class_names

# Prefetch the data for optimal performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# Simplified data augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# Normalize the images to the range the pre-trained model expects
preprocess_input = tf.keras.applications.efficientnet.preprocess_input

# Create the base model from the pre-trained EfficientNetB0
base_model = tf.keras.applications.EfficientNetB0(
    input_shape=(img_height, img_width, 3),
    include_top=False,
    weights='imagenet'
)

# Unfreeze some layers of the base model for fine-tuning
base_model.trainable = True
for layer in base_model.layers[:-20]:
    layer.trainable = False

# Define the number of classes
num_classes = len(class_names)

# Create the model
model = models.Sequential([
    data_augmentation,
    layers.Lambda(preprocess_input),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# Define callbacks for early stopping and learning rate reduction
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00001)

# Train the model
epochs = 30  # Keeping a higher number of epochs with early stopping
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model
loss, accuracy = model.evaluate(test_dataset)
print(f'Test accuracy: {accuracy}')
# Out:
# Found 800 files belonging to 20 classes.
# Found 200 files belonging to 20 classes.
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 426ms/step - accuracy: 0.2907 - loss: 2.5268 - val_accuracy: 0.7350 - val_loss: 0.8526 - learning_rate: 0.0010
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 342ms/step - accuracy: 0.8716 - loss: 0.5099 - val_accuracy: 0.8350 - val_loss: 0.5297 - learning_rate: 0.0010
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 354ms/step - accuracy: 0.9195 - loss: 0.3053 - val_accuracy: 0.8800 - val_loss: 0.3702 - learning_rate: 0.0010
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 338ms/step - accuracy: 0.9636 - loss: 0.1563 - val_accuracy: 0.8950 - val_loss: 0.2763 - learning_rate: 0.0010
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 335ms/step - accuracy: 0.9601 - loss: 0.1280 - val_accuracy: 0.9300 - val_loss: 0.2964 - learning_rate: 0.0010
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 335ms/step - accuracy: 0.9810 - loss: 0.0943 - val_accuracy: 0.9350 - val_loss: 0.2520 - learning_rate: 0.0010
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - accuracy: 0.9780 - loss: 0.0788 - val_accuracy: 0.9550 - val_loss: 0.1966 - learning_rate: 0.0010
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 358ms/step - accuracy: 0.9772 - loss: 0.0790 - val_accuracy: 0.9350 - val_loss: 0.2841 - learning_rate: 0.0010
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - accuracy: 0.9731 - loss: 0.0819 - val_accuracy: 0.9400 - val_loss: 0.3118 - learning_rate: 0.0010
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - accuracy: 0.9762 - loss: 0.0627 - val_accuracy: 0.9400 - val_loss: 0.2346 - learning_rate: 0.0010
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 345ms/step - accuracy: 0.9930 - loss: 0.0278 - val_accuracy: 0.9500 - val_loss: 0.2269 - learning_rate: 2.0000e-04
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 343ms/step - accuracy: 0.9831 - loss: 0.0642 - val_accuracy: 0.9550 - val_loss: 0.2141 - learning_rate: 2.0000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.9624 - loss: 0.1724
# Test accuracy: 0.9549999833106995

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Define paths
train_dir = 'dataset/train'
test_dir = 'dataset/test'

# Load datasets
batch_size = 32
img_height = 224
img_width = 224

train_dataset = image_dataset_from_directory(
    train_dir,
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width)
)

test_dataset = image_dataset_from_directory(
    test_dir,
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width)
)

# Retrieve class names
class_names = train_dataset.class_names

# Prefetch the data for optimal performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# Data augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

base_model = tf.keras.applications.Xception(
    input_shape=(img_height, img_width, 3),
    include_top=False,
    weights='imagenet'
)
preprocess_input = tf.keras.applications.xception.preprocess_input

# Unfreeze some layers of the base model for fine-tuning
base_model.trainable = True
for layer in base_model.layers[:-20]:
    layer.trainable = False

# Define the number of classes
num_classes = len(class_names)

# Create the model
inputs = layers.Input(shape=(img_height, img_width, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)
model = models.Model(inputs, outputs)

# # Create the model
# model = models.Sequential([
#     data_augmentation,
#     layers.Lambda(preprocess_input),
#     base_model,
#     layers.GlobalAveragePooling2D(),
#     layers.Dense(512, activation='relu'),
#     layers.Dropout(0.5),
#     layers.Dense(num_classes, activation='softmax')
# ])

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# Define callbacks for early stopping and learning rate reduction
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00001)

# Train the model
epochs = 30  # Increased number of epochs with early stopping
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model
loss, accuracy = model.evaluate(test_dataset)
print(f'Test accuracy: {accuracy}')
# Out:
# Found 800 files belonging to 20 classes.
# Found 200 files belonging to 20 classes.
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.0846 - loss: 3.7230 - val_accuracy: 0.3000 - val_loss: 2.6904 - learning_rate: 1.0000e-04
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3831 - loss: 2.1865 - val_accuracy: 0.4650 - val_loss: 2.3166 - learning_rate: 1.0000e-04
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.6174 - loss: 1.3108 - val_accuracy: 0.6450 - val_loss: 1.9861 - learning_rate: 1.0000e-04
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.7028 - loss: 0.9407 - val_accuracy: 0.7050 - val_loss: 1.6858 - learning_rate: 1.0000e-04
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8070 - loss: 0.6563 - val_accuracy: 0.7550 - val_loss: 1.4035 - learning_rate: 1.0000e-04
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.8489 - loss: 0.4902 - val_accuracy: 0.8000 - val_loss: 1.1803 - learning_rate: 1.0000e-04
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.8717 - loss: 0.3994 - val_accuracy: 0.8500 - val_loss: 0.9502 - learning_rate: 1.0000e-04
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9359 - loss: 0.2496 - val_accuracy: 0.8650 - val_loss: 0.7748 - learning_rate: 1.0000e-04
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9332 - loss: 0.2419 - val_accuracy: 0.8950 - val_loss: 0.6440 - learning_rate: 1.0000e-04
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9563 - loss: 0.1852 - val_accuracy: 0.9100 - val_loss: 0.4925 - learning_rate: 1.0000e-04
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9522 - loss: 0.1644 - val_accuracy: 0.9250 - val_loss: 0.4090 - learning_rate: 1.0000e-04
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9790 - loss: 0.0952 - val_accuracy: 0.9200 - val_loss: 0.3430 - learning_rate: 1.0000e-04
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9746 - loss: 0.0999 - val_accuracy: 0.9300 - val_loss: 0.3047 - learning_rate: 1.0000e-04
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9692 - loss: 0.1058 - val_accuracy: 0.9350 - val_loss: 0.2639 - learning_rate: 1.0000e-04
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9840 - loss: 0.0717 - val_accuracy: 0.9350 - val_loss: 0.2387 - learning_rate: 1.0000e-04
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9840 - loss: 0.0662 - val_accuracy: 0.9400 - val_loss: 0.2457 - learning_rate: 1.0000e-04
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9852 - loss: 0.0744 - val_accuracy: 0.9350 - val_loss: 0.2342 - learning_rate: 1.0000e-04
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9824 - loss: 0.0580 - val_accuracy: 0.9350 - val_loss: 0.2409 - learning_rate: 1.0000e-04
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9873 - loss: 0.0501 - val_accuracy: 0.9350 - val_loss: 0.2387 - learning_rate: 1.0000e-04
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9903 - loss: 0.0577 - val_accuracy: 0.9350 - val_loss: 0.2427 - learning_rate: 1.0000e-04
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9885 - loss: 0.0582 - val_accuracy: 0.9450 - val_loss: 0.2274 - learning_rate: 2.0000e-05
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9890 - loss: 0.0453 - val_accuracy: 0.9500 - val_loss: 0.2258 - learning_rate: 2.0000e-05
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9915 - loss: 0.0477 - val_accuracy: 0.9500 - val_loss: 0.2272 - learning_rate: 2.0000e-05
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9961 - loss: 0.0331 - val_accuracy: 0.9500 - val_loss: 0.2242 - learning_rate: 2.0000e-05
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9908 - loss: 0.0408 - val_accuracy: 0.9450 - val_loss: 0.2215 - learning_rate: 2.0000e-05
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9839 - loss: 0.0490 - val_accuracy: 0.9450 - val_loss: 0.2231 - learning_rate: 2.0000e-05
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9891 - loss: 0.0432 - val_accuracy: 0.9450 - val_loss: 0.2263 - learning_rate: 2.0000e-05
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9789 - loss: 0.0649 - val_accuracy: 0.9450 - val_loss: 0.2203 - learning_rate: 2.0000e-05
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9767 - loss: 0.0734 - val_accuracy: 0.9500 - val_loss: 0.2154 - learning_rate: 2.0000e-05
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9933 - loss: 0.0360 - val_accuracy: 0.9500 - val_loss: 0.2164 - learning_rate: 2.0000e-05
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 652ms/step - accuracy: 0.9442 - loss: 0.2384
# Test accuracy: 0.949999988079071

# %%
# # Save the model using the SavedModel format
# model.save('indonesian_food_classifier_saved_model.keras')

# # Load the saved model
# model = tf.keras.models.load_model('indonesian_food_classifier_saved_model.keras')

# # Convert the model to TFLite format with optimizations
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# converter.optimizations = [tf.lite.Optimize.DEFAULT]
# tflite_model = converter.convert()

# # Save the optimized TFLite model
# with open('indonesian_food_classifier_optimized.tflite', 'wb') as f:
#     f.write(tflite_model)
